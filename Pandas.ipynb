# %% [markdown]
# <a href="https://colab.research.google.com/github/amaansadat/SRDT/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
labels=['a','b','c']
mylist=[10,20,30]
arr=np.array([10,20,30])
d={'a':10,'b':20,'c':30}

# %%
pd.Series(data=mylist)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(index=labels,data=mylist)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(mylist,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(data=arr,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
sl=pd.Series([sum,print,len])

# %%
sl
# Out:
# 0      <built-in function sum>
# 1    <built-in function print>
# 2      <built-in function len>
# dtype: object

# %%
sl[1]([1,2,3,4,5,6,7,8])
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
ser1=pd.Series([1,2,5,4],index=['USA','Germany','Italy','Japan'])
ser1
# Out:
# USA        1
# Germany    2
# Italy      5
# Japan      4
# dtype: int64

# %%
ser2=pd.Series([1,2,3,4],index=['USA','Germany','USSR','Japan'])
ser2
# Out:
# USA        1
# Germany    2
# USSR       3
# Japan      4
# dtype: int64

# %%
ser1+ser2
# Out:
# Germany    4.0
# Italy      NaN
# Japan      8.0
# USA        2.0
# USSR       NaN
# dtype: float64

# %%
ser1-ser2
# Out:
# Germany    0.0
# Italy      NaN
# Japan      0.0
# USA        0.0
# USSR       NaN
# dtype: float64

# %%
ser1/ser2
# Out:
# Germany    1.0
# Italy      NaN
# Japan      1.0
# USA        1.0
# USSR       NaN
# dtype: float64

# %%
ser1*2
# Out:
# USA         2
# Germany     4
# Italy      10
# Japan       8
# dtype: int64
